# %%
# !pip install bs4
# !pip install requests
# Out:
# Requirement already satisfied: bs4 in c:\users\harshit gupta\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\harshit gupta\anaconda3\lib\site-packages (from bs4) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\harshit gupta\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.2.1)
# Requirement already satisfied: requests in c:\users\harshit gupta\anaconda3\lib\site-packages (2.26.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\harshit gupta\anaconda3\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\harshit gupta\anaconda3\lib\site-packages (from requests) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\harshit gupta\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\harshit gupta\anaconda3\lib\site-packages (from requests) (1.26.7)

# %%
# Write a python program to display all the header tags from wikipedia.org

from bs4 import BeautifulSoup
import requests

page = requests.get('https://en.wikipedia.org/wiki/Main_Page')
page

soup = BeautifulSoup(page.content)
soup.text
# Out:
# '\n\n\nWikipedia, the free encyclopedia\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nMain Page\n\nFrom Wikipedia, the free encyclopedia\n\n\n\nJump to navigation\nJump to search\n\n\n\nWelcome to Wikipedia,\nthe free encyclopedia that anyone can edit.\n6,525,859 articles in English\n\n\n\n\nFrom today\'s featured article\n\n\n\n\nCarsten Borchgrevink (1864–1934) was an Anglo-Norwegian polar explorer and a pioneer of modern Antarctic travel. He was a precursor of Robert Falcon Scott, Ernest Shackleton, Roald Amundsen and others associated with the Heroic Age of Antarctic Exploration. He began his exploring career in 1894 by joining a Norwegian whaling expedition, from which he brought back a collection of the first specimens of vegetable life within the Antarctic Circle. From 1898 to 1900 Borchgrevink led the British-financed Southern Cross Expedition, which in 1899 became the first to overwinter on the Antarctic mainland and the first to visit the Great Ice Barrier in nearly 60 years. There he set a Farthest South record at 78°\xa050′\xa0S. He was one of three scientists sent to the Caribbean in 1902 by the National Geographic Society to report on the aftermath of the Mount Pelée disaster. Recognised and honoured by several countries, he received a handsome tribute in 1912 from Amundsen, conqueror of the South Pole. (Full\xa0article...)\n\n\nRecently featured: \nEdward Mitchell Bannister\nRed panda\nWill P. Brady\n\n\nArchive\nBy email\nMore featured articles\n\nDid you know\xa0...\n\n\n\nOlena Shevchenko\n\n... that a journalist dubbed Olena Shevchenko (pictured) as "probably the most famous lesbian in Ukraine"?\n... that the Electronic Arrays 9002 microprocessor was developed to get the company out of the calculator business, but instead led to their disappearance?\n... that Stig Millehaugen, who had escaped or attempted escape from prison multiple times, was given a prison furlough in 2022 and failed to return?\n... that posters for John Lindsay\'s 1965 New York City mayoral campaign told voters that "John Lindsay Cares About You"?\n... that an intestine-on-a-chip can model and mimic an organ?\n... that Charlie H. Hogan was called "king of engineers" after he became the first to drive a train at over 100 miles per hour (160\xa0km/h)?\n... that Internet activist Sally Burch was refused entry into Argentina because her presence was considered to be disruptive?\n... that the name of the "Mormons vs. Mullets" game was a play on the 1988 "Catholics vs. Convicts" game?\n\nArchive\nStart a new article\nNominate an article\n\n\n\n\nIn the news\n\n\nCale Makar\n\nIn ice hockey, the Colorado Avalanche defeat the Tampa Bay Lightning to win the Stanley Cup (Conn Smythe Trophy winner Cale Makar pictured).\nAt least twenty-one people are found dead in a nightclub in East London, South Africa.\nA mass shooting during LGBT pride celebrations in Oslo, Norway, leaves two people dead and twenty-one others injured.\nThe United States Supreme Court determines that abortion is not a protected constitutional right, overturning Roe v. Wade and Planned Parenthood v. Casey.\n\nOngoing: \nCOVID-19 pandemic\nRussian invasion of Ukraine\nRecent deaths: \nErnst Jacobi\nSam Gilliam\nMarlin Briscoe\nPaula Stafford\nGraham Skidmore\nGeorge Izo\n\nNominate an article\n\nOn this day\n\nJune 30: Asteroid Day\n\n\n\nTower Bridge, London\n\n1860 – Seven months after the publication of Charles Darwin\'s On the Origin of Species, prominent British scientists and philosophers participated in an evolution debate at the Oxford University Museum of Natural History.\n1894 – London\'s Tower Bridge (pictured), a combined bascule and suspension bridge over the River Thames, was inaugurated.\n1922 – An agreement was signed to end the United States occupation of the Dominican Republic.\n1960 – The Belgian Congo gained independence from colonial rule, beginning a period of instability that would lead to the dictatorship of Joseph- ...

# %%
#Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. name, rating, year of release) and make data frame.

from bs4 import BeautifulSoup
import requests

url=('https://www.imdb.com/list/ls055592025/')
response= requests.get(url)
response

soup=BeautifulSoup(response.content)
soup

title= soup.find('h3',class_="lister-item-header")
title.text

titles = []
for i in soup.find_all('h3',class_="lister-item-header"):
    titles.append(i.text)
    
titles
# Out:
# ['\n1.\nThe Godfather\n(1972)\n',
#  '\n2.\nThe Shawshank Redemption\n(1994)\n',
#  "\n3.\nSchindler's List\n(1993)\n",
#  '\n4.\nRaging Bull\n(1980)\n',
#  '\n5.\nCasablanca\n(1942)\n',
#  '\n6.\nCitizen Kane\n(1941)\n',
#  '\n7.\nGone with the Wind\n(1939)\n',
#  '\n8.\nThe Wizard of Oz\n(1939)\n',
#  "\n9.\nOne Flew Over the Cuckoo's Nest\n(1975)\n",
#  '\n10.\nLawrence of Arabia\n(1962)\n',
#  '\n11.\nVertigo\n(1958)\n',
#  '\n12.\nPsycho\n(1960)\n',
#  '\n13.\nThe Godfather Part II\n(1974)\n',
#  '\n14.\nOn the Waterfront\n(1954)\n',
#  '\n15.\nSunset Blvd.\n(1950)\n',
#  '\n16.\nForrest Gump\n(1994)\n',
#  '\n17.\nThe Sound of Music\n(1965)\n',
#  '\n18.\n12 Angry Men\n(1957)\n',
#  '\n19.\nWest Side Story\n(1961)\n',
#  '\n20.\nStar Wars\n(1977)\n',
#  '\n21.\n2001: A Space Odyssey\n(1968)\n',
#  '\n22.\nE.T. the Extra-Terrestrial\n(1982)\n',
#  '\n23.\nThe Silence of the Lambs\n(1991)\n',
#  '\n24.\nChinatown\n(1974)\n',
#  '\n25.\nThe Bridge on the River Kwai\n(1957)\n',
#  "\n26.\nSingin' in the Rain\n(1952)\n",
#  "\n27.\nIt's a Wonderful Life\n(1946)\n",
#  '\n28.\nDr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb\n(1964)\n',
#  '\n29.\nSome Like It Hot\n(1959)\n',
#  '\n30.\nBen-Hur\n(1959)\n',
#  '\n31.\nApocalypse Now\n(1979)\n',
#  '\n32.\nAmadeus\n(1984)\n',
#  '\n33.\nThe Lord of the Rings: The Return of the King\n(2003)\n',
#  '\n34.\nGladiator\n(2000)\n',
#  '\n35.\nTitanic\n(1997)\n',
#  '\n36.\nFrom Here to Eternity\n(1953)\n',
#  '\n37.\nSaving Private Ryan\n(1998)\n',
#  '\n38.\nUnforgiven\n(1992)\n',
#  '\n39.\nRaiders of the Lost Ark\n(1981)\n',
#  '\n40.\nRocky\n(1976)\n',
#  '\n41.\nA Streetcar Named Desire\n(1951)\n',
#  '\n42.\nThe Philadelphia Story\n(1940)\n',
#  '\n43.\nTo Kill a Mockingbird\n(1962)\n',
#  '\n44.\nAn American in Paris\n(1951)\n',
#  '\n45.\nThe Best Years of Our Lives\n(1946)\n',
#  '\n46.\nMy Fair Lady\n(1964)\n',
#  '\n47.\nA Clockwork Orange\n(1971)\n',
#  '\n48.\nDoctor Zhivago\n(1965)\n',
#  '\n49.\nThe Searchers\n(1956)\n',
#  '\n50.\nJaws\n(1975)\n',
#  '\n51.\nPatton\n(1970)\n',
#  '\n52.\nButch Cassidy and the Sundance Kid\n(1969)\n',
#  '\n53.\nThe Treasure of the Sierra Madre\n(1948)\n',
#  '\n54.\nIl buono, il brutto, il cattivo\n(1966)\n',
#  '\n55.\nThe Apartment\n(1960)\n',
#  '\n56.\nPlatoon\n(1986)\n',
#  '\n57.\nHigh Noon\n(1952)\n',
#  '\n58.\nBraveheart\n(1995)\n',
#  '\n59.\nDances with Wolves\n(1990)\n',
#  '\n60.\nJurassic Park\n(1993)\n',
#  '\n61.\nThe Exorcist\n(1973)\n',
#  '\n62.\nThe Pianist\n(2002)\n',
#  '\n63.\nGoodfellas\n(1990)\n',
#  '\n64.\nThe Deer Hunter\n(1978)\n',
#  '\n65.\nAll Quiet on the Western Front\n(1930)\n',
#  '\n66.\nBonnie and Clyde\n(1967)\n',
#  '\n67.\nThe French Connection\n(1971)\n',
#  '\n68.\nCity Lights\n(1931)\n',
#  '\n69.\nIt Happened One Night\n(1934)\n',
#  '\n70.\nA Place in the Sun\n(1951)\n',
#  '\n71.\nMidnight Cowboy\n(1969)\n',
#  '\n72.\nMr. Smith Goes to Washington\n(1939)\n',
#  '\n73.\nRain Man\n(1988)\n',
#  '\n74.\nAnnie Hall\n(1977)\n',
#  '\n75.\nFargo\n(1996)\n',
#  '\n76.\nGiant\n(1956)\n',
#  '\n77.\nShane\n(1953)\n',
#  '\n78.\nThe Grapes of Wrath\n(1940)\n',
#  '\n79.\nThe Green Mile\n(1999)\n',
#  '\n80.\nClose Encounters of the Third Kind\n(1977)\n',
#  '\n81.\nNashville\n(1975)\n',
#  '\n82.\nNetwork\n(1976)\n',
#  '\n83.\nThe Graduate\n(1967)\n',
#  '\n84.\nAmerican Graffiti\n(1973)\n',
#  '\n85.\nPulp Fiction\n(1994)\n',
#  '\n86.\nTerms of Endearment\n(1983)\n',
#  '\n87.\nGood Will Hunting\n(1997)\n',
#  '\n88.\nThe African Queen\n(1951)\n',
#  '\n89.\nStagecoach\n(1939)\n',
#  '\n90.\nMutiny on the Bounty\n(1935)\n',
#  '\n91.\nThe Great Dictator\n(1940)\n',
#  '\n92.\nDouble Indemnity\n(1944)\n',
#  '\n93.\nThe Maltese Falcon\n(1941)\n',
#  '\n94.\nWuthering Heights\n(1939)\n',
#  '\n95.\nTaxi Driver\n(1976)\n',
#  '\n96.\nRear Window\n(1954)\n',
#  '\n97.\nThe Third Man\n(1949)\n',
#  '\n98.\nRebel Without a Cause\n(1955)\n',
#  '\n99.\nNorth by Northwest\n(1959)\n',
#  '\n100.\nYankee Doodle Dandy\n(1942)\n']

# %%
import pandas as pd
df= pd.DataFrame(titles)
df
# Out:
#                                            0
# 0              \n1.\nThe Godfather\n(1972)\n
# 1   \n2.\nThe Shawshank Redemption\n(1994)\n
# 2           \n3.\nSchindler's List\n(1993)\n
# 3                \n4.\nRaging Bull\n(1980)\n
# 4                 \n5.\nCasablanca\n(1942)\n
# ..                                       ...
# 95              \n96.\nRear Window\n(1954)\n
# 96            \n97.\nThe Third Man\n(1949)\n
# 97    \n98.\nRebel Without a Cause\n(1955)\n
# 98       \n99.\nNorth by Northwest\n(1959)\n
# 99     \n100.\nYankee Doodle Dandy\n(1942)\n
#
# [100 rows x 1 columns]

# %%
#Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. name, rating, year of release) and make data frame.

from bs4 import BeautifulSoup
import requests

url=('https://www.imdb.com/india/top-rated-indian-movies/')
response= requests.get(url)
response

soup=BeautifulSoup(response.content)
soup

title= soup.find('td',class_="titleColumn")
title

titles = []
for i in soup.find_all('td',class_="titleColumn"):
    titles.append(i.text)
    
titles
# Out:
# ['\n      1.\n      Jai Bhim\n(2021)\n',
#  '\n      2.\n      Anbe Sivam\n(2003)\n',
#  '\n      3.\n      Golmaal\n(1979)\n',
#  '\n      4.\n      Nayakan\n(1987)\n',
#  '\n      5.\n      Pariyerum Perumal\n(2018)\n',
#  '\n      6.\n      3 Idiots\n(2009)\n',
#  '\n      7.\n      Apur Sansar\n(1959)\n',
#  '\n      8.\n      Manichitrathazhu\n(1993)\n',
#  '\n      9.\n      Black Friday\n(2004)\n',
#  '\n      10.\n      Kumbalangi Nights\n(2019)\n',
#  '\n      11.\n      C/o Kancharapalem\n(2018)\n',
#  '\n      12.\n      Taare Zameen Par\n(2007)\n',
#  '\n      13.\n      #Home\n(2021)\n',
#  '\n      14.\n      Vikram\n(2022)\n',
#  '\n      15.\n      Soorarai Pottru\n(2020)\n',
#  '\n      16.\n      Dangal\n(2016)\n',
#  '\n      17.\n      Kireedam\n(1989)\n',
#  '\n      18.\n      Kaithi\n(2019)\n',
#  '\n      19.\n      Jersey\n(2019)\n',
#  '\n      20.\n      Thevar Magan\n(1992)\n',
#  '\n      21.\n      Pather Panchali\n(1955)\n',
#  '\n      22.\n      Asuran\n(2019)\n',
#  '\n      23.\n      96\n(2018)\n',
#  '\n      24.\n      Visaaranai\n(2015)\n',
#  '\n      25.\n      Thalapathi\n(1991)\n',
#  '\n      26.\n      Natsamrat\n(2016)\n',
#  '\n      27.\n      Sarpatta Parambarai\n(2021)\n',
#  '\n      28.\n      Drishyam 2\n(2021)\n',
#  '\n      29.\n      Sardar Udham\n(2021)\n',
#  '\n      30.\n      Thani Oruvan\n(2015)\n',
#  '\n      31.\n      Aparajito\n(1956)\n',
#  '\n      32.\n      Vada Chennai\n(2018)\n',
#  '\n      33.\n      Jaane Bhi Do Yaaro\n(1983)\n',
#  '\n      34.\n      Khosla Ka Ghosla!\n(2006)\n',
#  '\n      35.\n      Drishyam\n(2013)\n',
#  '\n      36.\n      Chupke Chupke\n(1975)\n',
#  '\n      37.\n      Peranbu\n(2018)\n',
#  '\n      38.\n      Agent Sai Srinivasa Athreya\n(2019)\n',
#  '\n      39.\n      Anniyan\n(2005)\n',
#  '\n      40.\n      Mahanati\n(2018)\n',
#  '\n      41.\n      Super Deluxe\n(2019)\n',
#  '\n      42.\n      Satya\n(1998)\n',
#  '\n      43.\n      Bangalore Days\n(2014)\n',
#  '\n      44.\n      Premam\n(2015)\n',
#  '\n      45.\n      Ratsasan\n(2018)\n',
#  '\n      46.\n      Devasuram\n(1993)\n',
#  '\n      47.\n      Bhaag Milkha Bhaag\n(2013)\n',
#  '\n      48.\n      Gangs of Wasseypur\n(2012)\n',
#  '\n      49.\n      Aruvi\n(2016)\n',
#  '\n      50.\n      Andhadhun\n(2018)\n',
#  '\n      51.\n      Drishyam\n(2015)\n',
#  '\n      52.\n      Kannathil Muthamittal\n(2002)\n',
#  '\n      53.\n      Guide\n(1965)\n',
#  '\n      54.\n      Shahid\n(2012)\n',
#  '\n      55.\n      Chithram\n(1988)\n',
#  '\n      56.\n      Iruvar\n(1997)\n',
#  '\n      57.\n      Sairat\n(2016)\n',
#  '\n      58.\n      Zindagi Na Milegi Dobara\n(2011)\n',
#  '\n      59.\n      Paan Singh Tomar\n(2012)\n',
#  '\n      60.\n      Vikram Vedha\n(2017)\n',
#  '\n      61.\n      Tumbbad\n(2018)\n',
#  '\n      62.\n      Mudhalvan\n(1999)\n',
#  '\n      63.\n      Dhuruvangal Pathinaaru\n(2016)\n',
#  '\n      64.\n      Black\n(2005)\n',
#  '\n      65.\n      Spadikam\n(1995)\n',
#  '\n      66.\n      Chhichhore\n(2019)\n',
#  '\n      67.\n      Swades: We, the People\n(2004)\n',
#  '\n      68.\n      Chak De! India\n(2007)\n',
#  '\n      69.\n      Jo Jeeta Wohi Sikandar\n(1992)\n',
#  '\n      70.\n      Pudhu Pettai\n(2006)\n',
#  '\n      71.\n      Papanasam\n(2015)\n',
#  '\n      72.\n      Pyaasa\n(1957)\n',
#  '\n      73.\n      Soodhu Kavvum\n(2013)\n',
#  '\n      74.\n      PK\n(2014)\n',
#  '\n      75.\n      Munna Bhai M.B.B.S.\n(2003)\n',
#  '\n      76.\n      Article 15\n(2019)\n',
#  '\n      77.\n      Mandela\n(2021)\n',
#  '\n      78.\n      Queen\n(2013)\n',
#  '\n      79.\n      Talvar\n(2015)\n',
#  '\n      80.\n      Uri: The Surgical Strike\n(2019)\n',
#  '\n      81.\n      Kaakkaa Muttai\n(2014)\n',
#  '\n      82.\n      OMG: Oh My God!\n(2012)\n',
#  '\n      83.\n      Lagaan: Once Upon a Time in India\n(2001)\n',
#  '\n      84.\n      Jigarthanda\n(2014)\n',
#  '\n      85.\n      Sarfarosh\n(1999)\n',
#  '\n      86.\n      Udaan\n(2010)\n',
#  '\n      87.\n      Barfi!\n(2012)\n',
#  '\n      88.\n      Theeran Adhigaaram Ondru\n(2017)\n',
#  '\n      89.\n      Sholay\n(1975)\n',
#  '\n      90.\n      Ustad Hotel\n(2012)\n',
#  '\n      91.\n      Hera Pheri\n(2000)\n',
#  '\n      92.\n      The Legend of Bhagat Singh\n(2002)\n',
#  '\n      93.\n      Angoor\n(1982)\n',
#  '\n      94.\n      Rang De Basanti\n(2006)\n',
#  '\n      95.\n      Baasha\n(1995)\n',
#  '\n      96.\n      Masaan\n(2015)\n',
#  '\n      97.\n      Kahaani\n(2012)\n',
#  '\n      98.\n      Baahubali 2: The Conclusion\n(2017)\n',
#  '\n      99.\n      Dil Chahta Hai\n(2001)\n',
#  '\n      100.\n      Maheshinte Prathikaaram\n(2016)\n',
#  '\n      101.\n      Roja\n(1992)\n',
#  '\n      102.\n      A Wednesday\n(2008)\n',
#  '\n      103.\n      Pink\n(2016)\n',
#  '\n      104.\n      Nil Battey Sannata\n(2015)\n',
#  '\n      105.\n      Iqbal\n(2005)\n',
#  '\n      106.\n      Virumandi\n(2004)\n',
#  '\n      107.\n      Lage Raho Munna Bhai\n(2006)\n',
#  '\n      108.\n      Pithamagan\n(2003)\n',
#  '\n      109.\n      K.G.F: Chapter 2\n(2022)\n',
#  '\n      110.\n      Kaun Pravin Tambe?\n(2022)\n',
#  '\n      111.\n      Shershaah\n(2021)\n',
#  '\n      112.\n      Charulata\n(1964)\n',
#  '\n      113.\n      Anand\n(1971)\n',
#  '\n      114.\n      Section 375\n(2019)\n',
#  '\n      115.\n      Alai Payuthey\n(2000)\n',
#  '\n      116.\n      777 Charlie\n(2022)\n',
#  '\n      117.\n      Omkara\n(2006)\n',
#  '\n      118.\n      Bajrangi Bhaijaan\n(2015)\n',
#  '\n      119.\n      Bombay\n(1995)\n',
#  '\n      120.\n      Lucia\n(2013)\n',
#  '\n      121.\n      Oru Vadakkan Veeragatha\n(1989)\n',
#  '\n      122.\n      Bommarillu\n(2006)\n',
#  '\n      123.\n      K.G.F: Chapter 1\n(2018)\n',
#  '\n      124.\n      The Great Indian Kitchen\n(2021)\n',
#  '\n      125.\n      Indian\n(1996)\n',
#  '\n      126.\n      Haider\n(2014)\n',
#  '\n      127.\n      Jana Gana Mana\n(2022)\n',
#  '\n      128.\n      Rangasthalam\n(2018)\n',
#  '\n      129.\n      Dilwale Dulhania Le Jayenge\n(1995)\n',
#  '\n      130.\n      Mughal-E-Azam\n(1960)\n',
#  '\n      131.\n      Special Chabbis\n(2013)\n',
#  '\n      132.\n      Maqbool\n(2003)\n',
#  '\n      133.\n      Athadu\n(2005)\n',
#  '\n      134.\n      Andaz Apna Apna\n(1994)\n',
#  '\n      135.\n      Thadam\n(2019)\n',
#  '\n      136.\n      Maanaadu\n(2021)\n',
#  '\n      137.\n      Padayappa\n(1999)\n',
#  '\n      138.\n      Pelli Choopulu\n(2016)\n',
#  '\n      139.\n      Gulaal\n(2009)\n',
#  '\n      140.\n      Vaaranam Aayiram\n(2008)\n',
#  '\n      141.\n      Android Kunjappan Version 5.25\n(2019)\n',
#  '\n      142.\n      Gully Boy\n(2019)\n',
#  '\n      143.\n      Ugly\n(2013)\n',
#  '\n      144.\n      Naduvula Konjam Pakkatha Kaanom\n(2012)\n',
#  '\n      145.\n      Badhaai ho\n(2018)\n',
#  '\n      146.\n      Deewaar\n(1975)\n',
#  '\n      147.\n      Vaastav: The Reality\n(1999)\n',
#  '\n      148.\n      Company\n(2002)\n',
#  '\n      149.\n      Kshanam\n(2016)\n',
#  '\n      150.\n      Padosan\n(1968)\n',
#  '\n      151.\n      Evaru\n(2019)\n',
#  '\n      152.\n      Ulidavaru Kandanthe\n(2014)\n',
#  '\n      153.\n      Aadukalam\n(2011)\n',
#  '\n      154.\n      Maanagaram\n(2017)\n',
#  '\n      155.\n      Dev.D\n(2009)\n',
#  '\n      156.\n      Nayattu\n(2021)\n',
#  '\n      157.\n      Thondimuthalum Dhriksakshiyum\n(2017)\n',
#  '\n      158.\n      My Name Is Khan\n(2010)\n',
#  '\n      159.\n      Pranchiyettan and the Saint\n(2010)\n',
#  '\n      160.\n      Take Off\n(2017)\n',
#  '\n      161.\n      Kal Ho Naa Ho\n(2003)\n',
#  '\n      162.\n      Baishe Srabon\n(2011)\n',
#  '\n      163.\n      Arjun Reddy\n(2017)\n',
#  '\n      164.\n      Jab We Met\n(2007)\n',
#  '\n      165.\n      Manjhi: The Mountain Man\n(2015)\n',
#  '\n      166.\n      Super 30\n(2019)\n',
#  '\n      167.\n      Mukkabaaz\n(2017)\n',
#  '\n      168.\n      Dil Bechara\n(2020)\n',
#  '\n      169.\n      Ayyappanum Koshiyum\n(2020)\n',
#  '\n      170.\n      RRR (Rise Roar Revolt)\n(2022)\n',
#  '\n      171.\n      Border\n(1997)\n',
#  '\n      172.\n      Deiva Thirumagal\n(2011)\n',
#  '\n      173.\n      Karnan\n(2021)\n',
#  '\n      174.\n      Ship of Theseus\n(2012)\n',
#  '\n      175.\n      Jalsaghar\n(1958)\n',
#  '\n      176.\n      Padman\n(2018)\n',
#  '\n      177.\n      Vedam\n(2010)\n',
#  '\n      178.\n      Charlie\n(2015)\n',
#  '\n      179.\n      Salaam Bombay!\n(1988)\n',
#  '\n      180.\n      Bãhubali: The Beginning\n(2015)\n',
#  '\n      181.\n      Ankhon Dekhi\n(2013)\n',
#  '\n      182.\n      Baby\n(2015)\n',
#  '\n      183.\n      Pizza\n(2012)\n',
#  '\n      184.\n      Vinnaithaandi Varuvaayaa\n(2010)\n',
#  '\n      185.\n      Malik\n(2021)\n',
#  '\n      186.\n      English Vinglish\n(2012)\n',
#  '\n      187.\n      M.S. Dhoni: The Untold Story\n(2016)\n',
#  '\n      188.\n      Kirik Party\n(2016)\n',
#  '\n      189.\n      Lakshya\n(2004)\n',
#  '\n      190.\n      Hindi Medium\n(2017)\n',
#  '\n      191.\n      Dor\n(2006)\n',
#  '\n      192.\n      Airlift\n(2016)\n',
#  '\n      193.\n      Memories\n(2013)\n',
#  '\n      194.\n      Johnny Gaddaar\n(2007)\n',
#  '\n      195.\n      Joseph\n(2018)\n',
#  '\n      196.\n      Kaakha..Kaakha: The Police\n(2003)\n',
#  '\n      197.\n      Hey Ram\n(2000)\n',
#  '\n      198.\n      Gangaajal\n(2003)\n',
#  '\n      199.\n      The Tashkent Files\n(2019)\n',
#  '\n      200.\n      Vettaiyaadu Vilaiyaadu\n(2006)\n',
#  '\n      201.\n      Anjaam Pathiraa\n(2020)\n',
#  '\n      202.\n      Mumbai Police\n(2013)\n',
#  '\n      203.\n      Hridayam\n(2022)\n',
#  '\n      204.\n      The Lunchbox\n(2013)\n',
#  '\n      205.\n      Ab Tak Chhappan\n(2004)\n',
#  '\n      206.\n      Major\n(2022)\n',
#  '\n      207.\n      Okkadu\n(2003)\n',
#  '\n      208.\n      Unnaipol Oruvan\n(2009)\n',
#  '\n      209.\n      Secret Superstar\n(2017)\n',
#  '\n      210.\n      Angamaly Diaries\n(2017)\n',
#  '\n      211.\n      Pokiri\n(2006)\n',
#  '\n      212.\n      Thuppakki\n(2012)\n',
#  '\n      213.\n      Manam\n(2014)\n',
#  '\n      214.\n      Oopiri\n(2016)\n',
#  '\n      215.\n      Vicky Donor\n(2012)\n',
#  '\n      216.\n      Mother India\n(1957)\n',
#  '\n      217.\n      Ghilli\n(2004)\n',
#  '\n      218.\n      Veer-Zaara\n(2004)\n',
#  '\n      219.\n      RangiTaranga\n(2015)\n',
#  '\n      220.\n      Stanley Ka Dabba\n(2011)\n',
#  '\n      221.\n      Rock On!!\n(2008)\n',
#  '\n      222.\n      Udta Punjab\n(2016)\n',
#  '\n      223.\n      Mimi\n(2021)\n',
#  '\n      224.\n      Nayak: The Real Hero\n(2001)\n',
#  '\n      225.\n      Mr. India\n(1987)\n',
#  '\n      226.\n      Kaththi\n(2014)\n',
#  '\n      227.\n      Badla\n(2019)\n',
#  '\n      228.\n      Raazi\n(2018)\n',
#  '\n      229.\n      Minnal Murali\n(2021)\n',
#  '\n      230.\n      Happy Days\n(2007)\n',
#  '\n      231.\n      Dia\n(2020)\n',
#  '\n      232.\n      Sonchiriya\n(2019)\n',
#  '\n      233.\n      Dasvidaniya\n(2008)\n',
#  '\n      234.\n      Thulladha Manamum Thullum\n(1999)\n',
#  '\n      235.\n      Kai po che!\n(2013)\n',
#  '\n      236.\n      Poove Unakkaga\n(1996)\n',
#  '\n      237.\n      Aayirathil Oruvan\n(2010)\n',
#  '\n      238.\n      Joji\n(2021)\n',
#  '\n      239.\n      Goodachari\n(2018)\n',
#  '\n      240.\n      Ko\n(2011)\n',
#  '\n      241.\n      Don\n(1978)\n',
#  '\n      242.\n      Aligarh\n(2015)\n',
#  '\n      243.\n      Guru\n(2007)\n',
#  '\n      244.\n      Ennu Ninte Moideen\n(2015)\n',
#  '\n      245.\n      Kapoor & Sons\n(2016)\n',
#  '\n      246.\n      Colour Photo\n(2020)\n',
#  '\n      247.\n      24\n(2016)\n',
#  '\n      248.\n      Velaiilla Pattadhari\n(2014)\n',
#  '\n      249.\n      Rockstar\n(2011)\n',
#  '\n      250.\n      Oye Lucky! Lucky Oye!\n(2008)\n']

# %%
#Write s python program to display list of respected former presidents of India(i.e. Name , Term of office) from https://presidentofindia.nic.in/former-presidents.htm

from bs4 import BeautifulSoup
import requests

url=('https://presidentofindia.nic.in/former-presidents.htm')
response= requests.get(url)
response

soup=BeautifulSoup(response.content)
soup

title= soup.find('div',class_="presidentListing")
title.text

titles = []
for i in soup.find_all('div',class_="presidentListing"):
    titles.append(i.text)
    
titles
# Out:
# ['\nShri Pranab Mukherjee (1935-2020)\nTerm of Office: 25 July, 2012 to 25 July, 2017 \nhttp://pranabmukherjee.nic.in\n',
#  '\nSmt Pratibha Devisingh Patil (birth - 1934)\nTerm of Office: 25 July, 2007 to 25 July, 2012 \nhttp://pratibhapatil.nic.in\n',
#  '\nDR. A.P.J. Abdul Kalam (1931-2015)\nTerm of Office: 25 July, 2002 to 25 July, 2007 \nhttp://abdulkalam.nic.in\n',
#  '\nShri K. R. Narayanan (1920 - 2005)\nTerm of Office: 25 July, 1997 to 25 July, 2002 \n',
#  '\nDr Shankar Dayal Sharma (1918-1999)\nTerm of Office: 25 July, 1992 to 25 July, 1997 \n',
#  '\nShri R Venkataraman (1910-2009)\nTerm of Office: 25 July, 1987 to 25 July, 1992 \n',
#  '\nGiani Zail Singh (1916-1994)\nTerm of Office: 25 July, 1982 to 25 July, 1987 \n',
#  '\nShri Neelam Sanjiva Reddy (1913-1996)\nTerm of Office: 25 July, 1977 to 25 July, 1982 \n',
#  '\nDr. Fakhruddin Ali Ahmed (1905-1977)\nTerm of Office: 24 August, 1974 to 11 February, 1977\n',
#  '\nShri Varahagiri Venkata Giri (1894-1980)\nTerm of Office: 3 May, 1969 to 20 July, 1969 and 24 August, 1969 to 24 August, 1974\n',
#  '\nDr. Zakir Husain (1897-1969)\nTerm of Office: 13 May, 1967 to 3 May, 1969\n',
#  '\nDr. Sarvepalli Radhakrishnan (1888-1975)\nTerm of Office: 13 May, 1962 to 13 May, 1967\n',
#  '\nDr. Rajendra Prasad (1884-1963) \nTerm of Office: 26 January, 1950 to 13 May, 1962\n']

# %%
import pandas as pd
df= pd.DataFrame(titles)
df
# Out:
#                                                     0
# 0   \nShri Pranab Mukherjee (1935-2020)\nTerm of O...
# 1   \nSmt Pratibha Devisingh Patil (birth - 1934)\...
# 2   \nDR. A.P.J. Abdul Kalam (1931-2015)\nTerm of ...
# 3   \nShri K. R. Narayanan (1920 - 2005)\nTerm of ...
# 4   \nDr Shankar Dayal Sharma (1918-1999)\nTerm of...
# 5   \nShri R Venkataraman (1910-2009)\nTerm of Off...
# 6   \nGiani Zail Singh (1916-1994)\nTerm of Office...
# 7   \nShri Neelam Sanjiva Reddy (1913-1996)\nTerm ...
# 8   \nDr. Fakhruddin Ali Ahmed (1905-1977)\nTerm o...
# 9   \nShri Varahagiri Venkata Giri (1894-1980)\nTe...
# 10  \nDr. Zakir Husain (1897-1969)\nTerm of Office...
# 11  \nDr. Sarvepalli Radhakrishnan (1888-1975)\nTe...
# 12  \nDr. Rajendra Prasad (1884-1963) \nTerm of Of...

# %%
#Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape: 
#a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.

from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

url = 'https://www.icc-cricket.com/rankings/mens/team-rankings/odi'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

data = []
table = soup.find('table', {'class':'table'})
table_body = table.find('tbody')

rows = table_body.find_all('tr')

for tr in rows[:10]:
    data= []
    cols=tr.find_all('td')
    for td in cols:
        data.append(td.text.strip())
    print(data)
# Out:
# ['1', 'New Zealand\nNZ', '12', '1,505', '125']
# ['2', 'England\nENG', '22', '2,756', '125']
# ['3', 'Pakistan\nPAK', '19', '2,005', '106']
# ['4', 'India\nIND', '22', '2,304', '105']
# ['5', 'Australia\nAUS', '23', '2,325', '101']
# ['6', 'South Africa\nSA', '19', '1,872', '99']
# ['7', 'Bangladesh\nBAN', '24', '2,275', '95']
# ['8', 'Sri Lanka\nSL', '29', '2,658', '92']
# ['9', 'West Indies\nWI', '32', '2,306', '72']
# ['10', 'Afghanistan\nAFG', '18', '1,238', '69']

# %%
#b) Top 10 ODI Batsmen along with the records of their team and rating.

from bs4 import BeautifulSoup
import requests

url=('https://www.icc-cricket.com/rankings/mens/player-rankings/odi')
response= requests.get(url)
response

soup=BeautifulSoup(response.content)
soup

title= soup.find('tr',class_="table-body")
title.text

titles = []
for i in soup.find_all('tr',class_="table-body"):
    titles.append(i.text)
    
titles
# Out:
# ['\n\n\n\n                                    2\n                                \n\n\n(0)\n\n\n\n\nImam-ul-Haq\n\n\n\nPAK\n\n815\n',
#  '\n\n\n\n                                    3\n                                \n\n\n(0)\n\n\n\n\nVirat Kohli\n\n\n\nIND\n\n811\n',
#  '\n\n\n\n                                    4\n                                \n\n\n(0)\n\n\n\n\nRohit Sharma\n\n\n\nIND\n\n791\n',
#  '\n\n\n\n                                    5\n                                \n\n\n(0)\n\n\n\n\nQuinton de Kock\n\n\n\nSA\n\n789\n',
#  '\n\n\n\n                                    6\n                                \n\n\n(0)\n\n\n\n\nRoss Taylor\n\n\n\nNZ\n\n775\n',
#  '\n\n\n\n                                    7\n                                \n\n\n(0)\n\n\n\n\nRassie van der Dussen\n\n\n\nSA\n\n769\n',
#  '\n\n\n\n                                    8\n                                \n\n\n(0)\n\n\n\n\nJonny Bairstow\n\n\n\nENG\n\n752\n',
#  '\n\n\n\n                                    9\n                                \n\n\n(0)\n\n\n\n\nDavid Warner\n\n\n\nAUS\n\n737\n',
#  '\n\n\n\n                                    10\n                                \n\n\n\n\n\nThis player has moved up in the rankings since the previous rankings update\n\n\n\n\nShai Hope\n\n\n\nWI\n\n718\n',
#  '\n\n\n\n                                    2\n                                \n\n\n(0)\n\n\n\n\nMatt Henry\n\n\n\nNZ\n\n683\n',
#  '\n\n\n\n                                    3\n                                \n\n\n(0)\n\n\n\n\nShaheen Afridi\n\n\n\nPAK\n\n681\n',
#  '\n\n\n\n                                    4\n                                \n\n\n(0)\n\n\n\n\nChris Woakes\n\n\n\nENG\n\n680\n',
#  '\n\n\n\n                                    5\n                                \n\n\n(0)\n\n\n\n\nJasprit Bumrah\n\n\n\nIND\n\n679\n',
#  '\n\n\n\n                                    6\n                                \n\n\n\n\n(1)\nThis player has moved up in the rankings since the previous rankings update\n\n\n\n\nJosh Hazlewood\n\n\n\nAUS\n\n679\n',
#  '\n\n\n\n                                    7\n                                \n\n\n\n\n(1)\nThis player has moved down in the rankings since the previous rankings update\n\n\n\n\nMujeeb Ur Rahman\n\n\n\nAFG\n\n676\n',
#  '\n\n\n\n                                    8\n                                \n\n\n(0)\n\n\n\n\nMehedi Hasan\n\n\n\nBAN\n\n661\n',
#  '\n\n\n\n                                    9\n                                \n\n\n(0)\n\n\n\n\nMohammad Nabi\n\n\n\nAFG\n\n657\n',
#  '\n\n\n\n                                    10\n                                \n\n\n(0)\n\n\n\n\nShakib Al Hasan\n\n\n\nBAN\n\n657\n',
#  '\n\n\n\n                                    2\n                                \n\n\n(0)\n\n\n\n\nMohammad Nabi\n\n\n\nAFG\n\n325\n',
#  '\n\n\n\n                                    3\n                                \n\n\n(0)\n\n\n\n\nRashid Khan\n\n\n\nAFG\n\n290\n',
#  '\n\n\n\n                                    4\n                                \n\n\n(0)\n\n\n\n\nChris Woakes\n\n\n\nENG\n\n265\n',
#  '\n\n\n\n                                    5\n                                \n\n\n(0)\n\n\n\n\nColin de Grandhomme\n\n\n\nNZ\n\n262\n',
#  '\n\n\n\n                                    6\n                                \n\n\n(0)\n\n\n\n\nMitchell Santner\n\n\n\nNZ\n\n260\n',
#  '\n\n\n\n                                    7\n                                \n\n\n(0)\n\n\n\n\nBen Stokes\n\n\n\nENG\n\n251\n',
#  '\n\n\n\n                                    8\n                                \n\n\n(0)\n\n\n\n\nZeeshan Maqsood\n\n\n\nOMA\n\n238\n',
#  '\n\n\n\n                                    9\n                                \n\n\n(0)\n\n\n\n\nImad Wasim\n\n\n\nPAK\n\n234\n',
#  '\n\n\n\n                                    10\n                                \n\n\n(0)\n\n\n\n\nMehedi Hasan\n\n\n\nBAN\n\n233\n',
#  '\n\n\n\n                                    2\n                                \n\n\n(0)\n\n\n\n\nImam-ul-Haq\n\n\n\nPAK\n\n815\n',
#  '\n\n\n\n                                    3\n                                \n\n\n(0)\n\n\n\n\nVirat Kohli\n\n\n\nIND\n\n811\n',
#  '\n\n\n\n                                    4\n                                \n\n\n(0)\n\n\n\n\nRohit Sharma\n\n\n\nIND\n\n791\n',
#  '\n\n\n\n                                    5\n                                \n\n\n(0)\n\n\n\n\nQuinton de Kock\n\n\n\nSA\n\n789\n',
#  '\n\n\n\n                                    6\n                                \n\n\n(0)\n\n\n\n\nRoss Taylor\n\n\n\nNZ\n\n775\n',
#  '\n\n\n\n                                    7\n                                \n\n\n(0)\n\n\n\n\nRassie van der Dussen\n\n\n\nSA\n\n769\n',
#  '\n\n\n\n                                    8\n                                \n\n\n(0)\n\n\n\n\nJonny Bairstow\n\n\n\nENG\n\n752\n',
#  '\n\n\n\n                                    9\n                                \n\n\n(0)\n\n\n\n\nDavid Warner\n\n\n\nAUS\n\n737\n',
#  '\n\n\n\n                                    10\n                                \n\n\n\n\n\nThis player has moved up in the rankings since the previous rankings update\n\n\n\n\nShai Hope\n\n\n\nWI\n\n718\n',
#  '\n\n\n\n                                    2\n                                \n\n\n(0)\n\n\n\n\nMatt Henry\n\n\n\nNZ\n\n683\n',
#  '\n\n\n\n                                    3\n                                \n\n\n(0)\n\n\n\n\nShaheen Afridi\n\n\n\nPAK\n\n681\n',
#  '\n\n\n\n                                    4\n                                \n\n\n(0)\n\n\n\n\nChris Woakes\n\n\n\nENG\n\n680\n',
#  '\n\n\n\n                                    5\n                                \n\n\n(0)\n\n\n\n\nJasprit Bumrah\n\n\n\nIND\n\n679\n',
#  '\n\n\n\n                                    6\n                                \n\n\n\n\n(1)\nThis player has moved up in the rankings since the previous rankings update\n\n\n\n\nJosh Hazlewood\n\n\n\nAUS\n\n679\n',
#  '\n\n\n\n                                    7\n                                \n\n\n\n\n(1)\nThis player has moved down in the rankings since the previous rankings update\n\n\n\n\nMujeeb Ur Rahman\n\n\n\nAFG\n\n676\n',
#  '\n\n\n\n                                    8\n                                \n\n\n(0)\n\n\n\n\nMehedi Hasan\n\n\n\nBAN\n\n661\n',
#  '\n\n\n\n                                    9\n                                \n\n\n(0)\n\n\n\n\nMohammad Nabi\n\n\n\nAFG\n\n657\n',
#  '\n\n\n\n                                    10\n                                \n\n\n(0)\n\n\n\n\nShakib Al Hasan\n\n\n\nBAN\n\n657\n',
#  '\n\n\n\n                                    2\n                                \n\n\n(0)\n\n\n\n\nMohammad Nabi\n\n\n\nAFG\n\n325\n',
#  '\n\n\n\n                                    3\n                                \n\n\n(0)\n\n\n\n\nRashid Khan\n\n\n\nAFG\n\n290\n',
#  '\n\n\n\n                                    4\n                                \n\n\n(0)\n\n\n\n\nChris Woakes\n\n\n\nENG\n\n265\n',
#  '\n\n\n\n                                    5\n                                \n\n\n(0)\n\n\n\n\nColin de Grandhomme\n\n\n\nNZ\n\n262\n',
#  '\n\n\n\n                                    6\n                                \n\n\n(0)\n\n\n\n\nMitchell Santner\n\n\n\nNZ\n\n260\n',
#  '\n\n\n\n                                    7\n                                \n\n\n(0)\n\n\n\n\nBen Stokes\n\n\n\nENG\n\n251\n',
#  '\n\n\n\n                                    8\n                                \n\n\n(0)\n\n\n\n\nZeeshan Maqsood\n\n\n\nOMA\n\n238\n',
#  '\n\n\n\n                                    9\n                                \n\n\n(0)\n\n\n\n\nImad Wasim\n\n\n\nPAK\n\n234\n',
#  '\n\n\n\n                                    10\n                                \n\n\n(0)\n\n\n\n\nMehedi Hasan\n\n\n\nBAN\n\n233\n']

# %%
#Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:
#a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.

from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

url = 'https://www.icc-cricket.com/rankings/womens/team-rankings/odi'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

data = []
table = soup.find('table', {'class':'table'})
table_body = table.find('tbody')

rows = table_body.find_all('tr')

for tr in rows[:10]:
    data= []
    cols=tr.find_all('td')
    for td in cols:
        data.append(td.text.strip())
    print(data)
# Out:
# ['1', 'Australia\nAUS', '29', '4,837', '167']
# ['2', 'South Africa\nSA', '32', '3,949', '123']
# ['3', 'England\nENG', '30', '3,531', '118']
# ['4', 'India\nIND', '29', '2,889', '100']
# ['5', 'New Zealand\nNZ', '31', '3,019', '97']
# ['6', 'West Indies\nWI', '30', '2,768', '92']
# ['7', 'Bangladesh\nBAN', '12', '930', '78']
# ['8', 'Pakistan\nPAK', '30', '1,962', '65']
# ['9', 'Sri Lanka\nSL', '8', '384', '48']
# ['10', 'Ireland\nIRE', '8', '351', '44']

# %%
# Write a python program to scrape mentioned news details from https://www.cnbc.com/world/?region=world :
#i) Headline
#ii) Time
#iii) News Link

from bs4 import BeautifulSoup
import requests

url=('https://www.cnbc.com/world/?region=world')
response= requests.get(url)
response

soup=BeautifulSoup(response.content)
soup

title= soup.find('div',class_="LatestNews-container")
title.text

titles = []
for i in soup.find_all('div',class_="LatestNews-container"):
    titles.append(i.text)
    
titles
# Out:
# ['17 Min AgoCoinbase seeks licenses in Europe as it looks to ramp up growth outside the U.S.',
#  "17 Min AgoHere's what's hot — and what's not — in fintech right now",
#  '1 Hour AgoEuropean markets set to continue declines as recession concerns persist',
#  '2 Hours AgoGrayscale sues SEC after rejection of bid to turn largest bitcoin fund into ETF',
#  '4 Hours AgoChina continues to snap up Russian coal at steep discounts',
#  '6 Hours AgoGoldman says buy these global stocks to play a $900 billion EV opportunity',
#  '6 Hours AgoChina Shenzhen stocks rise as data shows factory activity grew; Asia stocks slip',
#  "6 Hours AgoCramer's lightning round: I prefer Deere over Nutrien right here",
#  '6 Hours AgoCramer warns investors not to group all stocks of the same sector together ',
#  "6 Hours AgoCramer: Charts suggest the recent commodities boom 'is not long for the world'",
#  '7 Hours AgoPalantir CEO Alex Karp on fighting with Peter Thiel and progressives ',
#  '7 Hours AgoSpirit delays merger shareholder vote before meeting to continue deal talks ',
#  "7 Hours AgoPinterest improving boards to help people ‘take more action,' new CEO Ready says",
#  '7 Hours AgoBest trades on CNBC Wednesday: Find bargains among megacap tech stocks',
#  '7 Hours AgoStock futures are flat as S&P 500 tracks for worst first half since 1970',
#  "8 Hours AgoJudge lifts Trump's contempt order in New York civil probe",
#  "9 Hours AgoCoinFlex probably won't resume withdrawals Thursday as planned, says CEO",
#  '9 Hours AgoAmazon wants us to believe the robots are coming. But how useful will they be?',
#  '9 Hours AgoRH shares slide after company lowers its outlook for the year',
#  '10 Hours AgoThis former financial advisor now educates advisors on crypto',
#  "10 Hours AgoDebt collector 'pay to pay fees' are 'often illegal,' says consumer watchdog",
#  '10 Hours AgoRecession stars: The best stocks in every industry during economic downturns',
#  "11 Hours Ago'It's like going to the DMV online': How to buy Series I bonds",
#  '11 Hours AgoLongtime Google exec Nick Fox to take interim commerce business post',
#  '12 Hours AgoHow to calculate your credit utilization rate',
#  "12 Hours AgoBofA price-target cuts on Club chip stocks don't shake our long-term resolve",
#  '13 Hours AgoSupreme Court Justice Breyer to retire Thursday, replaced by Brown Jackson',
#  '13 Hours AgoStocks making the biggest moves midday: Bed Bath & Beyond, Carnival and more',
#  '13 Hours AgoLVMH buys California wine giant Joseph Phelps as high-end drinks market soars',
#  '13 Hours Ago25-year-old TikTok creator with 7 million followers saves 50% of her income']

# %%
#Write a python program to scrape the details of most downloaded articles from AI in last 90 days.
#https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles
#Scrape below mentioned details :
#i) Paper Title
#ii) Authors
#iii) Published Date
#iv) Paper URL 

from bs4 import BeautifulSoup
import requests

url=('https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles')
response= requests.get(url)
response

soup=BeautifulSoup(response.content)
soup

title= soup.find('ul',class_="sc-9zxyh7-0 ffmPq")
title.text

titles = []
for i in soup.find_all('ul',class_="sc-9zxyh7-0 ffmPq"):
    titles.append(i.text)
    
titles
# Out:
# ["Reward is enoughSilver, David, Singh, Satinder, Precup, Doina, Sutton, Richard S. Open AccessOctober 2021Making sense of raw inputEvans, Richard, Bošnjak, Matko and 5 moreOpen AccessOctober 2021Law and logic: A review from an argumentation perspectivePrakken, Henry, Sartor, Giovanni Open AccessOctober 2015Creativity and artificial intelligenceBoden, Margaret A. Open AccessAugust 1998Artificial cognition for social human–robot interaction: An implementationLemaignan, Séverin, Warnier, Mathieu and 3 moreOpen AccessJune 2017Explanation in artificial intelligence: Insights from the social sciencesMiller, Tim February 2019Making sense of sensory inputEvans, Richard, Hernández-Orallo, José and 3 moreOpen AccessApril 2021Conflict-based search for optimal multi-agent pathfindingSharon, Guni, Stern, Roni, Felner, Ariel, Sturtevant, Nathan R. Open AccessFebruary 2015Between MDPs and semi-MDPs: A framework for temporal abstraction in reinforcement learningSutton, Richard S., Precup, Doina, Singh, Satinder Open AccessAugust 1999The Hanabi challenge: A new frontier for AI researchBard, Nolan, Foerster, Jakob N. and 13 moreOpen AccessMarch 2020Evaluating XAI: A comparison of rule-based and example-based explanationsvan der Waa, Jasper, Nieuwburg, Elisabeth, Cremers, Anita, Neerincx, Mark Open AccessFebruary 2021Argumentation in artificial intelligenceBench-Capon, T.J.M., Dunne, Paul E. Open AccessOctober 2007Algorithms for computing strategies in two-player simultaneous move gamesBošanský, Branislav, Lisý, Viliam and 3 moreOpen AccessAugust 2016Multiple object tracking: A literature reviewLuo, Wenhan, Xing, Junliang and 4 moreApril 2021Selection of relevant features and examples in machine learningBlum, Avrim L., Langley, Pat Open AccessDecember 1997A survey of inverse reinforcement learning: Challenges, methods and progressArora, Saurabh, Doshi, Prashant August 2021Explaining individual predictions when features are dependent: More accurate approximations to Shapley valuesAas, Kjersti, Jullum, Martin, Løland, Anders Open AccessSeptember 2021A review of possible effects of cognitive biases on interpretation of rule-based machine learning modelsKliegr, Tomáš, Bahník, Štěpán, Fürnkranz, Johannes Open AccessJune 2021Integrating social power into the decision-making of cognitive agentsPereira, Gonçalo, Prada, Rui, Santos, Pedro A. Open AccessDecember 2016“That's (not) the output I expected!” On the role of end user expectations in creating explanations of AI systemsRiveiro, Maria, Thill, Serge Open AccessSeptember 2021Explaining black-box classifiers using post-hoc explanations-by-example: The effect of explanations and error-rates in XAI user studiesKenny, Eoin M., Ford, Courtney, Quinn, Molly, Keane, Mark T. Open AccessMay 2021Algorithm runtime prediction: Methods & evaluationHutter, Frank, Xu, Lin, Hoos, Holger H., Leyton-Brown, Kevin Open AccessJanuary 2014Wrappers for feature subset selectionKohavi, Ron, John, George H. Open AccessDecember 1997Commonsense visual sensemaking for autonomous driving – On generalised neurosymbolic online abduction integrating vision and semanticsSuchan, Jakob, Bhatt, Mehul, Varadarajan, Srikrishna Open AccessOctober 2021Quantum computation, quantum theory and AIYing, Mingsheng Open AccessFebruary 2010"]

# %%
#Write a python program to scrape mentioned details from dineout.co.in :
#i) Restaurant name
#ii) Cuisine
#iii) Location
#iv) Ratings
#v) Image URL


from bs4 import BeautifulSoup
import requests

url=('https://www.dineout.co.in/delhi-restaurants/buffet-special')
response= requests.get(url)
response

soup=BeautifulSoup(response.content)
soup

title= soup.find('div',class_="restnt-detail-wrap")
title.text

titles = []
for i in soup.find_all('div',class_="restnt-detail-wrap"):
    titles.append(i.text.replace('4.3232 votes','').replace('Dineout Pay',''))
    
titles
# Out:
# ['Castle BarbequeConnaught Place, Central Delhi₹ 2,000 for 2 (approx) | North Indian, Chinese',
#  'Jungle Jamboree3CS Mall,Lajpat Nagar - 3, South Delhi₹ 1,400 for 2 (approx) | North Indian, Asian, Italian',
#  'Castle BarbequePacific Mall,Tagore Garden, West Delhi₹ 2,000 for 2 (approx) | Chinese, North Indian',
#  'Cafe KnoshThe Leela Ambience Convention Hotel,Shahdara, East Delhi₹ 3,000 for 2 (approx) | Italian, Continental3 deals available1+1 on Lunch BuffetBuy Now1+1 on Dinner BuffetBuy Now1+1 on Sunday BrunchBuy Now+2 more deals- See less',
#  'The Barbeque CompanyGardens Galleria,Sector 38A, Noida₹ 1,700 for 2 (approx) | North Indian, Chinese4 deals availableLunch Buffet with 1 Soft Beverage (Applicable for 4 Pax)Buy NowWeekday Dinner Buffet (Applicable for 4 Pax)Buy NowLunch Buffet with 1 Soft Beverage (Applicable for 4 Pax)Buy NowWeekend Dinner Buffet (Applicable for 4 Pax)Buy Now+3 more deals- See less',
#  'India GrillHilton Garden Inn,Saket, South Delhi₹ 2,400 for 2 (approx) | North Indian, Italian',
#  'Delhi BarbequeTaurus Sarovar Portico,Mahipalpur, South Delhi₹ 1,800 for 2 (approx) | North Indian',
#  'The Monarch - Bar Be Que VillageIndirapuram Habitat Centre,Indirapuram, Ghaziabad₹ 1,900 for 2 (approx) | North Indian',
#  'World CafeVibe by The Lalit Traveller,Sector 35, Faridabad₹ 2,400 for 2 (approx) | North Indian, Italian',
#  'Indian Grill RoomSuncity Business Tower,Golf Course Road, Gurgaon₹ 2,200 for 2 (approx) | North Indian, Mughlai',
#  'Mad 4 Bar B QueSector 29, Faridabad₹ 800 for 2 (approx) | North Indian',
#  'Barbeque 29NIT, Faridabad₹ 1,500 for 2 (approx) | North Indian, Mughlai, Desserts, Beverages',
#  'GlasshouseDoubleTree By Hilton Gurugram Baani Square,Sector 50, Gurgaon₹ 3,400 for 2 (approx) | European, Italian, Asian, Continental']

# %%
#10) Write a python program to scrape the details of top publications from Google Scholar from
#https://scholar.google.com/citations?view_op=top_venues&hl=en
#ii) Publication

from bs4 import BeautifulSoup
import requests

url=('https://scholar.google.com/citations?view_op=top_venues&hl=en')
response= requests.get(url)
response

soup=BeautifulSoup(response.content)
soup

rank= soup.find('td',class_="gsc_mvt_p")
publication= soup.find('td',class_="gsc_mvt_t")
h5_index= soup.find('td',class_="gsc_mvt_n")
h5_median= soup.find('td',class_="gsc_mvt_n")
title.text

titles = []
for i in soup.find_all('td',class_="gsc_mvt_t"):
         titles.append(i.text)
titles
# Out:
# ['Nature',
#  'The New England Journal of Medicine',
#  'Science',
#  'IEEE/CVF Conference on Computer Vision and Pattern Recognition',
#  'The Lancet',
#  'Advanced Materials',
#  'Nature Communications',
#  'Cell',
#  'International Conference on Learning Representations',
#  'Neural Information Processing Systems',
#  'JAMA',
#  'Chemical Reviews',
#  'Proceedings of the National Academy of Sciences',
#  'Angewandte Chemie',
#  'Chemical Society Reviews',
#  'Journal of the American Chemical Society',
#  'IEEE/CVF International Conference on Computer Vision',
#  'Nucleic Acids Research',
#  'International Conference on Machine Learning',
#  'Nature Medicine',
#  'Renewable and Sustainable Energy Reviews',
#  'Science of The Total Environment',
#  'Advanced Energy Materials',
#  'Journal of Clinical Oncology',
#  'ACS Nano',
#  'Journal of Cleaner Production',
#  'Advanced Functional Materials',
#  'Physical Review Letters',
#  'Scientific Reports',
#  'The Lancet Oncology',
#  'Energy & Environmental Science',
#  'IEEE Access',
#  'PLoS ONE',
#  'Science Advances',
#  'Journal of the American College of Cardiology',
#  'Applied Catalysis B: Environmental',
#  'Nature Genetics',
#  'BMJ',
#  'Circulation',
#  'European Conference on Computer Vision',
#  'International Journal of Molecular Sciences',
#  'Nature Materials',
#  'Chemical engineering journal',
#  'AAAI Conference on Artificial Intelligence',
#  'Journal of Materials Chemistry A',
#  'ACS Applied Materials & Interfaces',
#  'Nature Biotechnology',
#  'The Lancet Infectious Diseases',
#  'Frontiers in Immunology',
#  'Applied Energy',
#  'Nano Energy',
#  'Nature Energy',
#  'Meeting of the Association for Computational Linguistics (ACL)',
#  'The Astrophysical Journal',
#  'Gastroenterology',
#  'Nature Methods',
#  'IEEE Transactions on Pattern Analysis and Machine Intelligence',
#  'Cochrane Database of Systematic Reviews',
#  'Blood',
#  'Neuron',
#  'Nano Letters',
#  'Morbidity and Mortality Weekly Report',
#  'European Heart Journal',
#  'Nature Nanotechnology',
#  'ACS Catalysis',
#  'Nature Neuroscience',
#  'American Economic Review',
#  'Journal of High Energy Physics',
#  'IEEE Communications Surveys & Tutorials',
#  'Annals of Oncology',
#  'Nutrients',
#  'Accounts of Chemical Research',
#  'Immunity',
#  'Environmental Science & Technology',
#  'Nature Reviews. Molecular Cell Biology',
#  'Gut',
#  'Physical Review D',
#  'ACS Energy Letters',
#  'Monthly Notices of the Royal Astronomical Society',
#  'Conference on Empirical Methods in Natural Language Processing (EMNLP)',
#  'Clinical Infectious Diseases',
#  'Cell Metabolism',
#  'Nature Reviews Immunology',
#  'Joule',
#  'Nature Photonics',
#  'International Journal of Environmental Research and Public Health',
#  'Environmental Pollution',
#  'Computers in Human Behavior',
#  'Frontiers in Microbiology',
#  'Nature Physics',
#  'Small',
#  'Cell Reports',
#  'Molecular Cell',
#  'Clinical Cancer Research',
#  'Bioresource Technology',
#  'Journal of Business Research',
#  'Molecular Cancer',
#  'Sensors',
#  'Nature Climate Change',
#  'IEEE Internet of Things Journal']
